# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
name = "Gauri"
age = 20
city = "Mumbai"

print("Name:", name)
print("Age:", age)
print("City:", city)
# Out:
# Name: Gauri
# Age: 20
# City: Mumbai

# %%
a = 10
b = 5

print("Addition:", a + b)
print("Subtraction:", a - b)
print("Multiplication:", a * b)
print("Division:", a / b)
# Out:
# Addition: 15
# Subtraction: 5
# Multiplication: 50
# Division: 2.0

# %%
foods = ["Pizza", "Pasta", "Burger", "Momos"]

print("My favorite foods:")
print(foods)

# Accessing items
print("First food:", foods[0])
print("Last food:", foods[-1])
# Out:
# My favorite foods:
# ['Pizza', 'Pasta', 'Burger', 'Momos']
# First food: Pizza
# Last food: Momos

# %%
name = "Gauri Porwal"
age = 20
city = "Mumbai"
skills = ["Figma", "Canva", "Photoshop"]

print("----- BIO DATA -----")
print("Name:", name)
print("Age:", age)
print("City:", city)
print("Skills:", skills)
# Out:
# ----- BIO DATA -----
# Name: Gauri Porwal
# Age: 20
# City: Mumbai
# Skills: ['Figma', 'Canva', 'Photoshop']

# %%
# Personal Introduction Program

# Asking for user details
name = input("Enter your name: ")
age = input("Enter your age: ")
hobby = input("Enter your hobby: ")

# Displaying a friendly welcome message
print("\n---------- Welcome Message ----------")
print(f"Hello {name}! 👋")
print(f"You are {age} years old.")
print(f"It's cool that you enjoy {hobby}!")
print("Nice to meet you! 😊")
# Out:
# Enter your name:  Gauri Porwal
# Enter your age:  20
# Enter your hobby:  Dancing
# ---------- Welcome Message ----------
# Hello Gauri Porwal! 👋
# You are 20 years old.
# It's cool that you enjoy Dancing!
# Nice to meet you! 😊
